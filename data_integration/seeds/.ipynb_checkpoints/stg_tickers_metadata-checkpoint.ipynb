# %%
import pandas as pd

# %%
df_btc_tickers = pd.read_csv(
        filepath_or_buffer='BTC_Tickers_Names_ETFS.csv',
        sep=';'
)

# %%
df_gold_tickers = pd.read_csv(
        filepath_or_buffer='GOLD_ETFS_NAMES.csv',
        sep=';'
)

# %%
df_gold_tickers = pd.concat([df_gold_tickers, df_btc_tickers], ignore_index=True)

# %%
def write_df_to_rds(df: pd.DataFrame, conn, schema, table_name):
    """
        This function writes an incoming Pandas Dataframe to the RDS Database. 
        
        parameters: 
            -df: incoming Pandas Dataframe
            -conn: incoming SQL Alchemy engine object 
            -schema: table schema within the RDS database
            -table_name: destination table name within the RDS database
    """
    
    df.to_sql(
        name=table_name, 
        con=conn, 
        schema=schema
    )
# Out:
#    Ticker                                        Ticker_name
# 0     GLD                                   SPDR Gold Shares
# 1     IAU                                 iShares Gold Trust
# 2    SGOL                     abrdn Physical Gold Shares ETF
# 3    GLDM                         SPDR Gold MiniShares Trust
# 4    AAAU                    Goldman Sachs Physical Gold ETF
# 5    OUNZ                             VanEck Merk Gold Trust
# 6     BAR                           GraniteShares Gold Trust
# 7    IAUM     iShares Gold Trust Micro ETF of Benef Interest
# 8     UGL                               ProShares Ultra Gold
# 9     GLL                          ProShares UltraShort Gold
# 10   IGLD            FT Vest Gold Strategy Target Income ETF
# 11   BGLD         FT Vest Gold Strategy Quarterly Buffer ETF
# 12    DBP                    Invesco DB Precious Metals Fund
# 13   IAUF                          iShares Gold Strategy ETF
# 14    DGP          DB Gold Double Long Exchange Traded Notes
# 15    DZZ         DB Gold Double Short Exchange Traded Notes
# 16   FGDL              Franklin Responsibly Sourced Gold ETF
# 17    DGZ                DB Gold Short Exchange Traded Notes
# 18   GBTC                            Grayscale Bitcoin Trust
# 19   IBIT                   IShares Bitcoin Trust Registered
# 20   FBTC                  Fidelity Wise Origin Bitcoin Fund
# 21   ARKB                           ARK 21Shares Bitcoin ETF
# 22   BITB                          Bitwise Bitcoin ETF Trust
# 23   BITO                     ProShares Bitcoin Strategy ETF
# 24   ARKW                   ARK Next Generation Internet ETF
# 25   BITX                            2x Bitcoin Strategy ETF
# 26   HODL                               VanEck Bitcoin Trust
# 27   BRRR                              Valkyrie Bitcoin Fund
# 28   BTCO                         Invesco Galaxy Bitcoin ETF
# 29   EZBC                               Franklin Bitcoin ETF
# 30   BITQ             Bitwise Crypto Industry Innovators ETF
# 31   WGMI                        Valkyrie Bitcoin Miners ETF
# 32   BTCW                            WisdomTree Bitcoin Fund
# 33    BTF            Valkyrie Bitcoin and Ether Strategy ETF
# 34   STCE                         Schwab Crypto Thematic ETF
# 35   BITS         Global X Blockchain & Bitcoin Strategy ETF
# 36   SPBC                   Simplify US Equity PLUS GBTC ETF
# 37   ARKA   ARK 21Shares Active Bitcoin Futures Strategy ETF
# 38   DEFI                                Hashdex Bitcoin ETF
# 39   BTOP  Bitwise Bitcoin and Ether Equal Weight Strateg...
# 40   SATO          Invesco Alerian Galaxy Crypto Economy ETF
# 41   BETH  ProShares Bitcoin & Ether Market Cap Weight St...
# 42   BETE  ProShares Bitcoin & Ether Equal Weight Strateg...
# 43   BLKC  Invesco Alerian Galaxy Blockchain Users and De...
# 44   BITC          Bitwise Bitcoin Strategy Optimum Roll ETF
# 45   BITW                       Bitwise 10 Crypto Index Fund
